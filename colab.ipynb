# %%
# !git clone https://github.com/Bryan0324/crescentmoon.git
# %cd crescentmoon
# !pip install -q ultralytics gymnasium "stable-baselines3[extra]" pyyaml

# %%
# !sed -i 's/device: cpu/device: cuda/' configs/default.yaml

# %%
# !python scripts/prepare_assets.py
# !python scripts/check_project.py

# %%
# !python scripts/run_stage2.py
# !python scripts/run_stage3.py
# !python scripts/make_report.py

# %%
# !zip -r -q results_colab.zip results docs/RESULTS.md
from google.colab import files
files.download('results_colab.zip')
